# %% [markdown]
# # Prepare Data for recipes.csv

# %% [markdown]
# ## Imports and Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

import sqlite3
import os

import kagglehub

plt.style.use('ggplot')
pd.set_option('display.max_columns', 200)

# %%
nr_df = pd.read_csv('Recipes/new_recipes.csv')

# %%
nr_df.head()
# Out:
#    recipe_id             recipe_name  prep_time_minutes  \
# 0          0  Chocolate Chip Cookies                 20
#
#             categories_json  star_rating  calories  protein_g  carbs_g  fat_g  \
# 0  ["dessert","vegetarian"]            6       NaN        NaN      NaN    NaN
#
#    fiber_g  sodium_mg                                       instructions  \
# 0      NaN        NaN  Mix wet ingredients. Add in dry ingredients. F...
#
#                                     ingredients_json  servings source
# 0  {"margarine":151,"white_sugar":133,"brown_suga...         4   user

# %%
nr_df.columns
# Out:
# Index(['recipe_id', 'recipe_name', 'prep_time_minutes', 'categories_json',
#        'star_rating', 'calories', 'protein_g', 'carbs_g', 'fat_g', 'fiber_g',
#        'sodium_mg', 'instructions', 'ingredients_json', 'servings', 'source'],
#       dtype='object')

# %%
print(nr_df.loc[0, 'ingredients_json'])
# Out:
# {"margarine":151,"white_sugar":133,"brown_sugar":147,"vanilla_extract":5.6,"eggs":67,"flour":240,"baking_soda":3.2,"baking_powder":1.3,"salt":4,"chocolate_chips":227}

# %% [markdown]
# ## Using recipes from kaggle

# %%
recipes_train_df = pd.read_json('Recipes/train.json')
recipes_test_df = pd.read_json('Recipes/test.json')

# %%
recipes_train_df.head()
# Out:
#       id      cuisine                                        ingredients
# 0  10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213       indian                [water, vegetable oil, wheat, salt]
# 4  13162       indian  [black pepper, shallots, cornflour, cayenne pe...

# %%
recipes_train_df.shape
# Out:
# (39774, 3)

# %%
recipes_test_df.shape
# Out:
# (9944, 2)

# %%
recipes_df = pd.concat([recipes_train_df, recipes_test_df], axis=0, ignore_index=True)

# %%
recipes_df.shape
# Out:
# (49718, 3)

# %%
recipes_df.head()
# Out:
#       id      cuisine                                        ingredients
# 0  10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213       indian                [water, vegetable oil, wheat, salt]
# 4  13162       indian  [black pepper, shallots, cornflour, cayenne pe...

# %% [markdown]
# hmmm so this data is for training a model to predict cuisine. Not really what I want, though it could be useful to help me createm my own model. I'll remember it, but for now I will need to find a different dataset for my recipes.

# %% [markdown]
# ## New Idea
